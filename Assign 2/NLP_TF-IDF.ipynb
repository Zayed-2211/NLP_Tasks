# %% [markdown]
# # Generating Documents

# %% [markdown]
# # Using GPT-2 for Documents Generation

# %%
from transformers import pipeline, set_seed

def generate_simple_document(phrase, seed=42, max_length=200):

    set_seed(seed)
    generator = pipeline('text-generation', model='gpt2')
    generated = generator(phrase, max_length=max_length, num_return_sequences=1)
    return generated[0]['generated_text']

# Different phrases for each field
phrases = {
    "technology": "The impact of artificial intelligence in our world",
    "healthcare": "healthcare field have seen major advancements ",
    "finance": "Emerging trends in personal finance management tools for the digital age"
}

documents = []
for field, phrase in phrases.items():
    document = generate_simple_document(phrase)
    documents.append(document)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
documents
# Out:
# ['The impact of artificial intelligence in our world is a massive one. Not just with information about everything in our bodies being spread in vast, uncontrolled regions, but with our brain being used so cheaply that we only pay attention when we smell this stuff.\n\nThis is also true while we are running away with things. In a perfect world our brains weren\'t such a big deal, we wouldn\'t need money to care if our brains were infected by a virus that\'s like Ebola. It wouldn\'t be an issue at all. We\'d be fine. It\'s not even a big worry.\n\n"Human intelligence, like everything else in the world – it can solve any problem – does not always solve all. No human has solved the world as successfully by our own efforts in solving it. Humans do understand our challenges of getting more and more smarter. And in fact, they understand the complexities we face, when it comes to making the most of them."\n\nWe\'re going to turn you',
#  "healthcare field have seen major advancements \xa0over time. Since , the average person living in a large metropolitan area in the United States has the equivalent of $, monthly insurance premiums. Since the Affordable Care Act went into effect, approximately  million Americans have been covered. According to the Kaiser Family Foundation, in , only . percent of Americans under  have insurance coverage at this age.\nThe Affordable Care Act has been associated with a decrease in the number and severity of type  diabetes and heart disease—both of which represent very serious health risks for millions of Americans and will cost millions of dollars per year. In addition, the ACA provides coverage for certain mental health conditions, such as alcoholism, which have serious consequences for the lives of so many in our nation. This has spurred numerous programs of health care reform that allow people to keep their own health insurance at home as they grow older, such as the National Heart, Lung, and Blood Institute's National Care program,",
#  'Emerging trends in personal finance management tools for the digital age have shown that consumers are being encouraged to use a variety of online applications as compared to traditional, online lenders. We conducted our research to determine which types of apps were the most popular among millennials. We found only one type of app and only one type of market that was highly competitive in terms of mobile sales.\n\nAmong the best apps in the market at leveraging mobile is Financing from the Apps app. Financing from the Apps app was the second biggest segment of app usage in the US. Overall, % of app users use Financing from the apps app, but only % use Financing from the traditional payment services.\n\nThe second largest segment for app use is Cash Card from the apps app. Cash Card in the App segment accounted for % of app usage, and Cash Card in the traditional payment services accounted for %, as determined by Consumer Reports.\n\nFinally, an unexpected third segment segment, Apps']

# %% [markdown]
# # Preprocessing documents

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

def preprocess_document(document, stem =True):
    
    # Break into lines and remove leading/trailing spaces
    lines = (line.strip() for line in document.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    cleaned_text = " ".join(chunks)

    # Tokenization
    tokens = word_tokenize(cleaned_text)

    # Remove punctuation and convert to lowercase
    tokens = [word.lower() for word in tokens if word.isalpha()]

    # Remove punctuation
    tokens = [word for word in tokens if word not in string.punctuation]

    # Remove stop words
    stop_words = set(stopwords.words("english"))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    
    # Stemming
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    if stem:
        # Get unique words using a set
        unique_words = set(stemmed_tokens)
    else:
        unique_words = set(filtered_tokens)

    return unique_words

# %% [markdown]
# # TF-IDF Builtin

# %%
cleaned_docs = []
for doc in documents:
    cleaned_docs.append(preprocess_document(doc))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Joining the words in each document back into a single string
preprocessed_texts = [" ".join(doc) for doc in cleaned_docs]

# Initialize the TfidfVectorizer 
vectorizer = TfidfVectorizer(stop_words = stopwords.words("english"), norm ='l2') # By default norm = l2: Sum of squares of vector elements is 1

# Fit and transform the documents
tfidf_matrix = vectorizer.fit_transform(documents)

# The tfidf_matrix now contains the Normalized TF-IDF scores. 
# Here's how you can get the feature names and scores for each document
feature_names = vectorizer.get_feature_names_out()
for doc_idx, doc in enumerate(tfidf_matrix):
    print(f"Document {doc_idx+1} TF-IDF Scores:")
    feature_index = doc.nonzero()[1]
    tfidf_scores = zip(feature_index, [doc[0, x] for x in feature_index])
    for word, score in [(feature_names[i], s) for (i, s) in tfidf_scores]:
        print(f"  {word}: {score:.4f}")
    print()
# Out:
# Document 1 TF-IDF Scores:
#   turn: 0.1004
#   going: 0.1004
#   making: 0.1004
#   comes: 0.1004
#   face: 0.1004
#   complexities: 0.1004
#   fact: 0.1004
#   smarter: 0.1004
#   getting: 0.1004
#   challenges: 0.1004
#   understand: 0.2008
#   humans: 0.1004
#   solving: 0.1004
#   efforts: 0.1004
#   successfully: 0.1004
#   solved: 0.1004
#   always: 0.1004
#   problem: 0.1004
#   solve: 0.2008
#   else: 0.1004
#   human: 0.2008
#   worry: 0.1004
#   even: 0.1004
#   fine: 0.1004
#   issue: 0.1004
#   ebola: 0.1004
#   like: 0.2008
#   virus: 0.1004
#   infected: 0.1004
#   care: 0.0764
#   money: 0.1004
#   need: 0.1004
#   deal: 0.1004
#   big: 0.2008
#   brains: 0.2008
#   perfect: 0.1004
#   things: 0.1004
#   away: 0.1004
#   running: 0.1004
#   true: 0.1004
#   also: 0.1004
#   stuff: 0.1004
#   smell: 0.1004
#   attention: 0.1004
#   pay: 0.1004
#   cheaply: 0.1004
#   used: 0.1004
#   brain: 0.1004
#   regions: 0.1004
#   uncontrolled: 0.1004
#   vast: 0.1004
#   spread: 0.1004
#   bodies: 0.1004
#   everything: 0.2008
#   information: 0.1004
#   one: 0.0764
#   massive: 0.1004
#   world: 0.4017
#   intelligence: 0.2008
#   artificial: 0.1004
#   impact: 0.1004
#
# Document 2 TF-IDF Scores:
#   program: 0.0844
#   institute: 0.0844
#   blood: 0.0844
#   lung: 0.0844
#   national: 0.1688
#   older: 0.0844
#   grow: 0.0844
#   home: 0.0844
#   keep: 0.0844
#   people: 0.0844
#   allow: 0.0844
#   reform: 0.0844
#   programs: 0.0844
#   numerous: 0.0844
#   spurred: 0.0844
#   nation: 0.0844
#   many: 0.0844
#   lives: 0.0844
#   consequences: 0.0844
#   alcoholism: 0.0844
#   conditions: 0.0844
#   mental: 0.0844
#   certain: 0.0844
#   provides: 0.0844
#   aca: 0.0844
#   addition: 0.0844
#   year: 0.0844
#   per: 0.0844
#   dollars: 0.0844
#   cost: 0.0844
#   millions: 0.1688
#   risks: 0.0844
#   health: 0.3376
#   serious: 0.1688
#   represent: 0.0844
#   disease: 0.0844
#   heart: 0.1688
#   diabetes: 0.0844
#   type: 0.0642
#   severity: 0.0844
#   number: 0.0844
#   decrease: 0.0844
#   associated: 0.0844
#   age: 0.0642
#   coverage: 0.1688
#   percent: 0.0844
#   foundation: 0.0844
#   family: 0.0844
#   kaiser: 0.0844
#   according: 0.0844
#   covered: 0.0844
#   americans: 0.2532
#   million: 0.0844
#   approximately: 0.0844
#   effect: 0.0844
#   went: 0.0844
#   act: 0.1688
#   affordable: 0.1688
#   premiums: 0.0844
#   insurance: 0.2532
#   monthly: 0.0844
#   equivalent: 0.0844
#   states: 0.0844
#   united: 0.0844
#   area: 0.0844
#   metropolitan: 0.0844
#   large: 0.0844
#   living: 0.0844
#   person: 0.0844
#   average: 0.0844
#   since: 0.1688
#   time: 0.0844
#   advancements: 0.0844
#   major: 0.0844
#   seen: 0.0844
#   field: 0.0844
#   healthcare: 0.0844
#   care: 0.2567
#
# Document 3 TF-IDF Scores:
#   third: 0.0566
#   unexpected: 0.0566
#   finally: 0.0566
#   reports: 0.0566
#   consumer: 0.0566
#   determined: 0.0566
#   accounted: 0.1132
#   card: 0.1698
#   cash: 0.1698
#   largest: 0.0566
#   services: 0.1132
#   payment: 0.1132
#   users: 0.0566
#   overall: 0.0566
#   us: 0.0566
#   usage: 0.1132
#   segment: 0.2830
#   biggest: 0.0566
#   second: 0.1132
#   financing: 0.2264
#   leveraging: 0.0566
#   best: 0.0566
#   sales: 0.0566
#   mobile: 0.1132
#   terms: 0.0566
#   competitive: 0.0566
#   highly: 0.0566
#   market: 0.1132
#   app: 0.5660
#   found: 0.0566
#   millennials: 0.0566
#   among: 0.1132
#   popular: 0.0566
#   apps: 0.3962
#   types: 0.0566
#   determine: 0.0566
#   research: 0.0566
#   conducted: 0.0566
#   lenders: 0.0566
#   traditional: 0.1698
#   compared: 0.0566
#   applications: 0.0566
#   online: 0.1132
#   variety: 0.0566
#   use: 0.2264
#   encouraged: 0.0566
#   consumers: 0.0566
#   shown: 0.0566
#   digital: 0.0566
#   tools: 0.0566
#   management: 0.0566
#   finance: 0.0566
#   personal: 0.0566
#   trends: 0.0566
#   emerging: 0.0566
#   type: 0.0861
#   age: 0.0430
#   one: 0.0861

# %%
print("Matrix Shape  = " , tfidf_matrix.toarray().shape)
# Out:
# Matrix Shape  =  (3, 193)

# %%
# Get the TF-IDF score of the first word in the first document
word_index = 0  
doc_index = 0 
print(tfidf_matrix[doc_index, :]) # Prints only non-zero values
# Out:
#   (0, 174)	0.10042428562400375
#   (0, 77)	0.10042428562400375
#   (0, 104)	0.10042428562400375
#   (0, 37)	0.10042428562400375
#   (0, 66)	0.10042428562400375
#   (0, 40)	0.10042428562400375
#   (0, 67)	0.10042428562400375
#   (0, 156)	0.10042428562400375
#   (0, 76)	0.10042428562400375
#   (0, 35)	0.10042428562400375
#   (0, 178)	0.2008485712480075
#   (0, 85)	0.10042428562400375
#   (0, 160)	0.10042428562400375
#   (0, 59)	0.10042428562400375
#   (0, 165)	0.10042428562400375
#   (0, 159)	0.10042428562400375
#   (0, 11)	0.10042428562400375
#   (0, 136)	0.10042428562400375
#   (0, 158)	0.2008485712480075
#   (0, 60)	0.10042428562400375
#   (0, 84)	0.2008485712480075
#   (0, 191)	0.10042428562400375
#   (0, 64)	0.10042428562400375
#   (0, 73)	0.10042428562400375
#   (0, 92)	0.10042428562400375
#   :	:
#   (0, 167)	0.10042428562400375
#   (0, 23)	0.10042428562400375
#   (0, 146)	0.10042428562400375
#   (0, 173)	0.10042428562400375
#   (0, 10)	0.10042428562400375
#   (0, 164)	0.10042428562400375
#   (0, 157)	0.10042428562400375
#   (0, 21)	0.10042428562400375
#   (0, 126)	0.10042428562400375
#   (0, 36)	0.10042428562400375
#   (0, 184)	0.10042428562400375
#   (0, 29)	0.10042428562400375
#   (0, 141)	0.10042428562400375
#   (0, 177)	0.10042428562400375
#   (0, 187)	0.10042428562400375
#   (0, 161)	0.10042428562400375
#   (0, 28)	0.10042428562400375
#   (0, 65)	0.2008485712480075
#   (0, 88)	0.10042428562400375
#   (0, 123)	0.07637525769853082
#   (0, 108)	0.10042428562400375
#   (0, 190)	0.401697142496015
#   (0, 91)	0.2008485712480075
#   (0, 19)	0.10042428562400375
#   (0, 86)	0.10042428562400375

# %% [markdown]
# # BONUS : TF-IDF from scratch

# %%
# Without stemmization as the default 
processed_docs = []
for d in documents:
    processed_docs.append(list(preprocess_document(d, False)))

# %%
from collections import Counter
import math
import numpy as np



vocabulary = set(word for doc in processed_docs for word in doc)
vocabulary = sorted(list(vocabulary))
vocab_index = {word: i for i, word in enumerate(vocabulary)}

# 1. Calculate TF for each word in each document, but now using a vector
tf_vectors = np.zeros((len(processed_docs), len(vocabulary)))
for doc_idx, doc in enumerate(processed_docs):
    tf_doc = Counter(doc)
    for word, count in tf_doc.items():
        if word in vocab_index:  # Check if word is in the vocabulary
            tf_vectors[doc_idx, vocab_index[word]] = count / len(doc)

# 2. Calculate IDF for each word using the same smoothing formula as scikit-learn
df_counts = np.zeros(len(vocabulary))
for doc in processed_docs:
    for word in set(doc):
        if word in vocab_index:
            df_counts[vocab_index[word]] += 1
            
idf_scores = np.log((1 + len(processed_docs)) / (1 + df_counts)) + 1  # Smoothing

# 3. Calculate TF-IDF scores
tfidf_matrix2 = tf_vectors * idf_scores

# 4. Normalize TF-IDF vectors (L2 norm)
tfidf_norm = np.linalg.norm(tfidf_matrix2, axis=1, keepdims=True)
scratch_tfidf_matrix = tfidf_matrix2 / tfidf_norm

# Check the shape of the matrix
print("Shape of the custom TF-IDF matrix:", scratch_tfidf_matrix.shape)
# Out:
# Shape of the custom TF-IDF matrix: (3, 193)

# %% [markdown]
# # Comparing Vocab of Built IN and From Scratch

# %%
for i, j in zip(vocabulary, vectorizer.get_feature_names_out()):
    print(i, " - ", j)
# Out:
# aca  -  aca
# according  -  according
# accounted  -  accounted
# act  -  act
# addition  -  addition
# advancements  -  advancements
# affordable  -  affordable
# age  -  age
# alcoholism  -  alcoholism
# allow  -  allow
# also  -  also
# always  -  always
# americans  -  americans
# among  -  among
# app  -  app
# applications  -  applications
# approximately  -  approximately
# apps  -  apps
# area  -  area
# artificial  -  artificial
# associated  -  associated
# attention  -  attention
# average  -  average
# away  -  away
# best  -  best
# big  -  big
# biggest  -  biggest
# blood  -  blood
# bodies  -  bodies
# brain  -  brain
# brains  -  brains
# card  -  card
# care  -  care
# cash  -  cash
# certain  -  certain
# challenges  -  challenges
# cheaply  -  cheaply
# comes  -  comes
# compared  -  compared
# competitive  -  competitive
# complexities  -  complexities
# conditions  -  conditions
# conducted  -  conducted
# consequences  -  consequences
# consumer  -  consumer
# consumers  -  consumers
# cost  -  cost
# coverage  -  coverage
# covered  -  covered
# deal  -  deal
# decrease  -  decrease
# determine  -  determine
# determined  -  determined
# diabetes  -  diabetes
# digital  -  digital
# dollars  -  disease
# ebola  -  dollars
# effect  -  ebola
# efforts  -  effect
# else  -  efforts
# emerging  -  else
# encouraged  -  emerging
# equivalent  -  encouraged
# even  -  equivalent
# everything  -  even
# face  -  everything
# fact  -  face
# family  -  fact
# field  -  family
# finally  -  field
# finance  -  finally
# financing  -  finance
# fine  -  financing
# found  -  fine
# foundation  -  found
# getting  -  foundation
# going  -  getting
# grow  -  going
# health  -  grow
# healthcare  -  health
# heart  -  healthcare
# highly  -  heart
# home  -  highly
# human  -  home
# humans  -  human
# impact  -  humans
# infected  -  impact
# information  -  infected
# institute  -  information
# insurance  -  institute
# intelligence  -  insurance
# issue  -  intelligence
# kaiser  -  issue
# keep  -  kaiser
# large  -  keep
# largest  -  large
# lenders  -  largest
# leveraging  -  lenders
# like  -  leveraging
# lives  -  like
# living  -  lives
# lung  -  living
# major  -  lung
# making  -  major
# management  -  making
# many  -  management
# market  -  many
# massive  -  market
# mental  -  massive
# metropolitan  -  mental
# millennials  -  metropolitan
# million  -  millennials
# millions  -  million
# mobile  -  millions
# money  -  mobile
# monthly  -  money
# nation  -  monthly
# national  -  nation
# need  -  national
# number  -  need
# numerous  -  number
# older  -  numerous
# one  -  older
# online  -  one
# overall  -  online
# pay  -  overall
# payment  -  pay
# people  -  payment
# per  -  people
# percent  -  per
# perfect  -  percent
# person  -  perfect
# personal  -  person
# popular  -  personal
# premiums  -  popular
# problem  -  premiums
# program  -  problem
# programs  -  program
# provides  -  programs
# reform  -  provides
# regions  -  reform
# reports  -  regions
# represent  -  reports
# research  -  represent
# risks  -  research
# running  -  risks
# sales  -  running
# second  -  sales
# seen  -  second
# segment  -  seen
# serious  -  segment
# services  -  serious
# severity  -  services
# shown  -  severity
# since  -  shown
# smarter  -  since
# smell  -  smarter
# solve  -  smell
# solved  -  solve
# solving  -  solved
# spread  -  solving
# spurred  -  spread
# states  -  spurred
# stuff  -  states
# successfully  -  stuff
# terms  -  successfully
# things  -  terms
# third  -  things
# time  -  third
# tools  -  time
# traditional  -  tools
# trends  -  traditional
# true  -  trends
# turn  -  true
# type  -  turn
# types  -  type
# uncontrolled  -  types
# understand  -  uncontrolled
# unexpected  -  understand
# united  -  unexpected
# us  -  united
# usage  -  us
# use  -  usage
# used  -  use
# users  -  used
# variety  -  users
# vast  -  variety
# virus  -  vast
# went  -  virus
# world  -  went
# worry  -  world
# would  -  worry
# year  -  year

# %% [markdown]
# # Comparing IDF Calculations

# %%
# After fitting TfidfVectorizer to your documents
idf_values_builtin = vectorizer.idf_
# Access your custom IDF values
idf_values_custom = idf_scores  

for i , j in zip(idf_values_builtin ,idf_values_custom):
    print(i , " - " ,j)
# Out:
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.2876820724517808  -  1.2876820724517808
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.2876820724517808  -  1.2876820724517808
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.2876820724517808
# 1.2876820724517808  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.2876820724517808
# 1.2876820724517808  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454
# 1.6931471805599454  -  1.6931471805599454

# %% [markdown]
# # Comparing Matrix values

# %%
doc_idx= 2
doc = tfidf_matrix[doc_idx].toarray().flatten()

print(f"Document {doc_idx+1} TF-IDF Scores:")
for idx, score in enumerate(doc[:10]):
    print(f"  {feature_names[idx]}: {score:.4f} - {scratch_tfidf_matrix[doc_idx, idx]}")
# Out:
# Document 3 TF-IDF Scores:
#   aca: 0.0000 - 0.0
#   according: 0.0000 - 0.0
#   accounted: 0.1132 - 0.13276197705502987
#   act: 0.0000 - 0.0
#   addition: 0.0000 - 0.0
#   advancements: 0.0000 - 0.0
#   affordable: 0.0000 - 0.0
#   age: 0.0430 - 0.10096890555047883
#   alcoholism: 0.0000 - 0.0
#   allow: 0.0000 - 0.0
